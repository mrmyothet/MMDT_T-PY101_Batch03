# %% [markdown]
# <a href="https://colab.research.google.com/github/mrmyothet/MMDT_T-PY101_Batch03/blob/myothet-ex-01/Myo_Thet/Ex01_Intro_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction

# %% [markdown]
# This section introduces the Python Programming uisng Colab. Follow the instructions and complete the exercises.

# %% [markdown]
# # Ex 1 : Check Version

# %% [markdown]
# Using the below cell, Import the required library and check the version of the python in your environment.

# %%
import sys
print(sys.version)
# Out:
# 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]

# %% [markdown]
# # Ex2 : Convert Currency.

# %% [markdown]
# Write a program that asks the user for the amount in usd and converts it to British pounds. The exchange rate is from usd to BP is given as 0.82

# %%
usd_amount = input ("Enter the amount in USD: ")
bp_amount = int(usd_amount) * 0.82
print("{} usd is equivalent to {} british pound".format(usd_amount, bp_amount))
# Out:
# Enter the amount in USD: 200
# 200 usd is equivalent to 164.0 british pound

# %% [markdown]
# # Ex 3: Temperature Converter

# %% [markdown]
# Write a program that convert temperature in Feranhite to celsius.

# %%
temp_f = input("Enger the temperature in Fahrenheit")
temp_c = ((int(temp_f) - 32)*5)/9
temp_c = int(temp_c)
print("{} Fahrenheit is equivalent to {} Celsius".format(temp_f, temp_c))
# Out:
# Enger the temperature in Fahrenheit83
# 83 Fahrenheit is equivalent to 28 Celsius

# %% [markdown]
# # Ex 4: Daily Maths

# %% [markdown]
# You are working in a retail shop. Write a program that computes the total cost for a customer that bought 3 differnt types of fruits : apple, orange, mango. Ask the user to enter the quantity and price for each type.

# %%
apple_qty = int(input("Enter the quantity of apple: "))
apple_price = int(input("Enter the price of apple:"))

orange_qty = int(input("Enter the quantity of orange: "))
orange_price = int(input("Enter the price of orange:"))

mango_qty = int(input("Enter the quantity of mango:"))
mango_price = int(input("Enter the price of mango:"))

total_cost = (apple_qty * apple_price) + (orange_qty * orange_price) + (mango_qty * mango_price)
print("Total cost for a customer that bought 3 types of fruits", total_cost)
# Out:
# Enter the quantity of apple: 1
# Enter the price of apple:10
# Enter the quantity of orange: 1
# Enter the price of orange:10
# Enter the quantity of mango:1
# Enter the price of mango:10
# Total cost for a customer that bought 3 types of fruits  30

# %% [markdown]
# # Ex 5 : Greeting

# %% [markdown]
# Write a program to greet the customer who provides the user name. Your program should ask the name of the customer and print "Hello + customer name"

# %%
customer_name = input("Please, input the user name")
print("Hello " + customer_name)
# Out:
# Please, input the user nameMyo Thet
# Hello Myo Thet

# %% [markdown]
# # Ex 6: Random Number
# Write a program that generates a random number, x, between 1 and 50, a random number y between 2 and 5, and computes x^y.

# %%
from random import randint
x = randint(1,50)
y = randint(2, 5)
print('A random number between 1 and 50: x =', x)
print('A random number between 2 and 5: y =', y)
x_exp_y = x**y
print('x^y: ', x_exp_y)
# Out:
# A random number between 1 and 50: x = 19
# A random number between 2 and 5: y = 4
# x^y:  130321

# %% [markdown]
# # Ex 7: Greet many times.
# Write a program that generates a random number between 1 and 10 and prints your name that many times.

# %%
times = randint(1, 10)
print(times)
print("Myo Thet \n" * times)
# Out:
# 9
# Myo Thet
# Myo Thet
# Myo Thet
# Myo Thet
# Myo Thet
# Myo Thet
# Myo Thet
# Myo Thet
# Myo Thet

# %% [markdown]
# # Ex 8: Computing.
# Write a program that asks the user to enter two numbers, x and y, and computes |x-y|/(x+y).

# %%
x = int(input("Enter a number, x: "))
y = int(input("Enter a number, y: "))
result = (abs(x-y)) / (x+y)
print("|x-y|/(x+y) = ", result)
# Out:
# Enter a number, x: 5
# Enter a number, y: 6
# |x-y|/(x+y) =  0.09090909090909091

# %% [markdown]
# # Ex 9: Computing
#
# Write a program that asks the user for a number of seconds and prints out how many minutes and seconds that is. For instance, 200 seconds is 3 minutes and 20 seconds.

# %%
input_seconds = int(input("Enter the number of seconds"))
minutes = int(input_seconds / 60)
seconds = input_seconds % 60
print("{} seconds is {} minutes and {} seconds.".format(input_seconds, minutes, seconds))
# Out:
# Enter the number of seconds200
# 200 seconds is 3 minutes and 20 seconds.

# %% [markdown]
# # Ex 10: Using Math Module
#
# Write a program that asks the user for a number and then prints out the sine, cosine, and tangent of that number.

# %%
import math
num = float(input("Enter a number:"))
sine_value = math.sin(num)
print("sine:", sine_value)

cosine_value = math.cos(num)
print("cosine:", cosine_value)

tangent_value = math.tan(num)
print("tangent:", tangent_value)
# Out:
# Enter a number:101.5
# sine: 0.82433986348825
# cosine: 0.5660952123664124
# tangent: 1.4561858950234072
